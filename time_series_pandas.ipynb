# %% [markdown]
# <a href="https://colab.research.google.com/github/AudryBarimbane/pandas_data_analysis_python/blob/main/time_series_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://github.com/MachineLearnia/Python-Machine-Learning/raw/master/Dataset/BTC-EUR.csv
# Out:
# --2021-09-29 07:15:05--  https://github.com/MachineLearnia/Python-Machine-Learning/raw/master/Dataset/BTC-EUR.csv
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/MachineLearnia/Python-Machine-Learning/master/Dataset/BTC-EUR.csv [following]
# --2021-09-29 07:15:05--  https://raw.githubusercontent.com/MachineLearnia/Python-Machine-Learning/master/Dataset/BTC-EUR.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 214959 (210K) [text/plain]
# Saving to: ‘BTC-EUR.csv’
#
# BTC-EUR.csv         100%[===================>] 209.92K  --.-KB/s    in 0.003s
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
bitcoin = pd.read_csv("BTC-EUR.csv",index_col='Date',parse_dates=True)

# %%
bitcoin.index
# Out:
# DatetimeIndex(['2011-10-04', '2011-10-05', '2011-10-06', '2011-10-07',
#                '2011-10-08', '2011-10-09', '2011-10-10', '2011-10-11',
#                '2011-10-12', '2011-10-13',
#                ...
#                '2019-09-25', '2019-09-26', '2019-09-27', '2019-09-28',
#                '2019-09-29', '2019-09-30', '2019-10-01', '2019-10-02',
#                '2019-10-03', '2019-10-04'],
#               dtype='datetime64[ns]', name='Date', length=2923, freq=None)

# %%
bitcoin.head()
# Out:
#              Open   High    Low  Close  Adj Close  Volume
# Date
# 2011-10-04  3.700  3.821  3.746  3.750      3.750    1357
# 2011-10-05  3.750  3.820  3.650  3.676      3.676    3349
# 2011-10-06  3.676  3.743  3.450  3.550      3.550    6642
# 2011-10-07  3.550  3.590  2.900  3.293      3.293    7135
# 2011-10-08  3.293  3.283  2.872  2.890      2.890    2007

# %%
bitcoin['Close']
# Out:
# Date
# 2011-10-04       3.750000
# 2011-10-05       3.676000
# 2011-10-06       3.550000
# 2011-10-07       3.293000
# 2011-10-08       2.890000
#                  ...
# 2019-09-30    7626.029785
# 2019-10-01    7625.560059
# 2019-10-02    7655.250000
# 2019-10-03    7516.790039
# 2019-10-04    7487.083496
# Name: Close, Length: 2923, dtype: float64

# %%
bitcoin['Close'].plot(figsize=(9,6))
plt.show()

# %%
bitcoin.index
# Out:
# DatetimeIndex(['2011-10-04', '2011-10-05', '2011-10-06', '2011-10-07',
#                '2011-10-08', '2011-10-09', '2011-10-10', '2011-10-11',
#                '2011-10-12', '2011-10-13',
#                ...
#                '2019-09-25', '2019-09-26', '2019-09-27', '2019-09-28',
#                '2019-09-29', '2019-09-30', '2019-10-01', '2019-10-02',
#                '2019-10-03', '2019-10-04'],
#               dtype='datetime64[ns]', name='Date', length=2923, freq=None)

# %%
bitcoin['2019']['Close'].plot()

# %%
bitcoin['2019-09']['Close'].plot()

# %%
bitcoin['2017':'2019']['Close'].plot()

# %%
bitcoin.loc['2017':'2019','Close'].plot()

# %%
bitcoin.loc['2019','Close'].resample('M').plot()
plt.show()

# %%
bitcoin.loc['2019','Close'].resample('M').mean().plot()
plt.show()

# %%
bitcoin.loc['2019','Close'].resample('W').mean().plot()
plt.show()

# %%
bitcoin.loc['2019','Close'].resample('2W').mean().plot()
plt.show()

# %%
bitcoin.loc['2019','Close'].resample('2W').std().plot()
plt.show()

# %%
plt.figure(figsize=(12,6))
bitcoin.loc['2019','Close'].plot()
bitcoin.loc['2019','Close'].resample('M').mean().plot(label='moyene par mois', lw=3, ls=':',alpha=0.8)
bitcoin.loc['2019','Close'].resample('W').mean().plot(label='moyene par semaine', lw=2, ls='--',alpha=0.8)

# %%
bitcoin.loc['2019','Close'].resample('W').agg(['mean','std','min','max'])
# Out:
#                     mean         std           min           max
# Date
# 2019-01-06   3413.619995   86.412199   3345.330078   3565.800049
# 2019-01-13   3308.722830  187.370818   3090.370117   3513.979980
# 2019-01-20   3193.085728   42.170285   3129.989990   3263.669922
# 2019-01-27   3139.568534   20.884335   3110.709961   3171.270020
# 2019-02-03   3010.647182   21.591732   2986.850098   3054.060059
# 2019-02-10   3093.135742  125.474356   2973.739990   3247.080078
# 2019-02-17   3196.895717   21.848029   3171.590088   3238.939941
# 2019-02-24   3472.014334  100.274323   3311.520020   3648.610107
# 2019-03-03   3361.397147   13.607572   3343.159912   3378.629883
# 2019-03-10   3427.681432   71.614973   3285.050049   3503.760010
# 2019-03-17   3460.784319   49.759121   3410.310059   3536.739990
# 2019-03-24   3531.442906   12.569157   3510.860107   3543.360107
# 2019-03-31   3584.785749   79.031293   3468.629883   3657.600098
# ...

# %%
m = bitcoin.loc['2019','Close'].resample('W').agg(['mean','std','min','max'])
plt.figure(figsize=(12,8))
m['mean']['2019'].plot(label='moyenne par semaine')
plt.fill_between(m.index,m['max'],m['min'],alpha=0.2,label='mn-max par semaine')

plt.legend()
plt.show()

# %%
bitcoin.loc['2019','Close'].rolling(window=7)
# Out:
# Rolling [window=7,center=False,axis=0]

# %%
bitcoin.loc['2019','Close'].rolling(window=7).mean().plot()
